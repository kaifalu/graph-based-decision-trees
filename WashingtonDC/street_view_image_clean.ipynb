# %%
# download images
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from street_view_image_downloader import StreetViewDownloader

#  Initialize the StreetViewDownloader:
api_key = "AIzaSyBgQrM9ePVSfbsRgWVb6nqfowPlfzDGenA"
downloader = StreetViewDownloader(api_key)

# %%
# Read station_info with attributes
station_info = pd.read_csv('Data/station_info_attribute_new.csv')
station_info['geometry'] = station_info[["longitude", "latitude"]].values.tolist()
station_info['geometry'] = station_info['geometry'].apply(Point)
station_info = gpd.GeoDataFrame(station_info)
station_info['Bike_Stop'] = 'Bike_Station' 
station_info.head()
# Out:
#    station_id   latitude  longitude                    geometry  TRACTCE  \
# 0     31100.0  38.900289 -77.042902  POINT (-77.04290 38.90029)    10700
# 1     31101.0  38.917766 -77.032083  POINT (-77.03208 38.91777)     4300
# 2     31102.0  38.929463 -77.027821  POINT (-77.02782 38.92946)     3000
# 3     31104.0  38.922865 -77.042517  POINT (-77.04252 38.92286)     3901
# 4     31105.0  38.926792 -77.032203  POINT (-77.03220 38.92679)     3000
#
#     pop_den  male_ratio  housing_unit_den  LU_diversity  bike_density  \
# 0  0.001615    0.467361          0.001530      1.410208     13.204279
# 1  0.014014    0.440458          0.010089      2.515274     11.946678
# 2  0.013170    0.409156          0.007601      1.914395      8.725216
# 3  0.017918    0.405918          0.014953      2.041013      7.670062
# 4  0.013170    0.409156          0.007601      1.914395      8.725216
#
#       Bike_Stop
# 0  Bike_Station
# 1  Bike_Station
# 2  Bike_Station
# 3  Bike_Station
# 4  Bike_Station

# %%
# download a single image
'''
for i in range (len(station_info)):
    lat, lng = station_info.iloc[i]['latitude'], station_info.iloc[i]['longitude']
    downloader.download_image(lat, lng, output_folder='Data/SVIs/ID_index' + str(station_info.index[i]), panorama=True)
'''

# %%
# Download Multiple Images:
# downloader.batch_download('test_data.csv', output_folder='test_images')

# %%
# lat, lng = 38.86557336107397, -76.97831040997501
# downloader.download_image(lat, lng, output_folder='Data/SVIs/ID_index' + '331', panorama=True)
